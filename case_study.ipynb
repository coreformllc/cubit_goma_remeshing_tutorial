# %%
import sys
import subprocess
import numpy
import meshio
import pyvista
pyvista.set_jupyter_backend( "trame" )

path_to_cubit = "/opt/Coreform-Cubit-2023.8/bin"
path_to_exodus = "/home/greg/apps/seacas/lib"
algebra_executable = "/home/greg/apps/seacas/bin/algebra"
goma_executable = "/home/greg/apps/goma/build/goma"

sys.path.append( path_to_cubit )
import cubit
cubit.init( [] )

sys.path.append( path_to_exodus )
import exodus

def main():
    generate_initial_mesh()
    run_goma()
    convert_results()

# %%
def run_goma():
    goma_command = f"{goma_executable} -a -i spreading_drop.inp"
    subprocess.check_call( goma_command, shell=True )

def convert_results():
    algebra_command = f"{algebra_executable} out_spreading_drop.e out_spreading_drop_last.e < algebra.in"
    subprocess.run( algebra_command, shell=True )
    meshio_command = "meshio convert out_spreading_drop_last.e out_spreading_drop.xdmf"
    subprocess.check_call( meshio_command, shell=True )

# %%
def remesh_droplet():
    ## Remeshing Example
    ## Bob Fermin & Kris Tjiptowidjojo
    ## Avery Dennison
    ## May 2023

    cubit.cmd( "reset" )

    cubit.cmd( "Set Exodus netcdf4 Off " )
    cubit.cmd( "Set Large Exodus Off " )
    cubit.cmd( "Set Overlap Maximum gap 0.0005" )
    cubit.cmd( "Set Node Constraint smart" )
    cubit.cmd( "Set Boolean Regularize on" )
    cubit.cmd( "Set Digits 10" )

    ## The Associativity commands below are
    ## essential for saving on export &
    ## recreating on import the geometry
    ## that needs to be remeshed.
    ##------------------------------
    cubit.cmd( "Set NodeSet Associativity ON" )
    cubit.cmd( "Set Associativity Complete ON" )
    ##------------------------------

    cubit.cmd( "import mesh geometry './Droplet.exoII' feature_angle 135.00  merge  deformed last" )
    cubit.cmd( "delete mesh surface 1 propagate" )

    cubit.cmd( "surface 1 size auto factor 3" )
    cubit.cmd( "mesh surface 1" )

def generate_initial_mesh():
    ## Remeshing Example
    ## Bob Fermin & Kris Tjiptowidjojo
    ## Avery Dennison
    ## May 2023

    cubit.cmd( "reset" )

    cubit.cmd( "Set Exodus netcdf4 Off" )
    cubit.cmd( "Set Large Exodus Off" )
    cubit.cmd( "Set Overlap Maximum gap 0.0005" )
    cubit.cmd( "Set Node Constraint smart" )
    cubit.cmd( "Set Boolean Regularize on" )
    cubit.cmd( "Set Digits 10" )

    ## The Associativity commands below are
    ## essential for saving on export &
    ## recreating on import the geometry
    ## that needs to be remeshed.
    ##------------------------------
    cubit.cmd( "Set NodeSet Associativity ON" )
    cubit.cmd( "Set Associativity Complete ON" )
    ##------------------------------

    Drop_Size = 0.05  # 500 microns

    ## Create a simple droplet resting on a substrate

    cubit.cmd( f"create surface circle radius {Drop_Size} zplane" )
    cubit.cmd( "webcut body 1 with plane yplane offset 0" )
    cubit.cmd( "delete Surface 2" )
    cubit.cmd( "webcut body All with plane xplane offset 0 imprint merge" )
    cubit.cmd( "compress all" )

    ## Mesh the droplet
    cubit.cmd( "surface all size auto factor 5" )
    cubit.cmd( "mesh surface all" )
    cubit.cmd( "surface all smooth scheme centroid area pull free" )
    cubit.cmd( "smooth surface all" )

    ## Add nodesets and sidesets to apply BCs

    cubit.cmd( "nodeset 1 add curve 1" )
    cubit.cmd( "nodeset 1 name 'MeshFence'" )
    cubit.cmd( "Sideset 1 add curve 1" )
    cubit.cmd( "Sideset 1 name 'MeshFence'" )

    cubit.cmd( "nodeset 100 add curve 2 5" )
    cubit.cmd( "nodeset 100 name 'Substrate'" )
    cubit.cmd( "Sideset 100 add curve 2 5" )
    cubit.cmd( "Sideset 100 name 'Substrate'" )

    cubit.cmd( "sideset 101 add curve 2" )
    cubit.cmd( "sideset 101 name 'Substrate-Right'" )
    cubit.cmd( "sideset 102 add curve 5" )
    cubit.cmd( "sideset 102 name 'Substrate-Left'" )

    cubit.cmd( "Nodeset 200 add curve 3 4" )
    cubit.cmd( "Nodeset 200 name 'FreeSurface'" )
    cubit.cmd( "Sideset 200 add curve 3 4" )
    cubit.cmd( "Sideset 200 name 'FreeSurface'" )

    cubit.cmd( "nodeset 1000 add vertex 1" )
    cubit.cmd( "nodeset 1000 name 'CA-Right'" )
    cubit.cmd( "nodeset 2000 add vertex 2" )
    cubit.cmd( "nodeset 2000 name 'CA-Left'" )

    ## Create the material block

    cubit.cmd( "block 1 add surface all" )
    cubit.cmd( "block 1 name 'Liquid'" )

    ## Set the element type

    cubit.cmd( "block 1  element type quad9" )

    ## Export the final mesh
    cubit.cmd( "save cub5 'drop_init_mesh.cub5' overwrite" )
    cubit.cmd( "export mesh 'drop_init_mesh.exoII' dimension 2 overwrite" )

# %%
main()
# Out:
# WARNING: Edges or nodes are not equivalent after node order correction.
# ...deleting 270 faces from database...
# ...deleting 570 edges from database...
# ...deleting 301 nodes from database...
# Journaled Command: reset
#
# Journaled Command: set exodus netcdf4 off
#
# Journaled Command: set large exodus file off
#
# Journaled Command: set overlap maximum gap 0.0005
#
# Journaled Command: set node constraint smart
#
# Journaled Command: set boolean regularize on
#
# Coordinates and lengths will be listed with up to 10 digits.
# To reset digits to default, use 'set digits -1'
# Journaled Command: set digits 10
#
# Nodeset Associativity is On:
# Exported mesh files will have data associating each node with geometry.
#
# Journaled Command: set nodeset associativity on
#
# Nodeset Associativity Complete for deformed geometry regeneration is On.
#
# Journaled Command: set associativity complete on
#
# Journaled Command: create surface circle radius 0.05 zplane
#
#
#
# Performing webcut operation...
# Created volume(s): 2
# Updated volume(s): 1
# Modified/Created volumes: 1 2
# Journaled Command: webcut body 1 with plane yplane offset 0
#
#
# Deleted 1 free surfaces
# Journaled Command: delete Surface 2
#
#
#
# Performing webcut operation...
# Created volume(s): 3
# Updated volume(s): 2
# Consolidated 0 pair of surfaces
# Curve 6 and 9 consolidated
# Consolidated 1 curves
# Consolidated 0 pairs of vertices
# Modified/Created volumes: 2 3
# Journaled Command: webcut body all with plane xplane offset 0 imprint merge
#
# Journaled Command: compress all
#
# Auto-sizing requested with sizing factor of 5.000000
# Calculating Auto Size
# 0   |    |    |    |    50   |    |    |    |  100
# **************************************************
# Journaled Command: surface all size auto factor 5
#
# Surface 1 meshing scheme automatically set to triprimitive.
# Surface 2 meshing scheme automatically set to triprimitive.
# Matching intervals successful.
# Surfaces 1, 2 meshing completed using scheme: triprimitive
# Generated 270 quads
# Journaled Command: mesh surface all
#
# Journaled Command: surface all smooth scheme centroid area pull free
#
# Centroid smoothing surface 1
# Processing...
# 0   |    |    |    |    50   |    |    |    |  100
# ***
# Smoothing of Surface 1 (surface 1) complete
# Centroid smoothing surface 2
# Processing...
# 0   |    |    |    |    50   |    |    |    |  100
# ***
# Smoothing of Surface 2 (surface 2) complete
# Journaled Command: smooth surface all
#
# Added Curve 1 to nodeset 1
# Journaled Command: nodeset 1 add curve 1
#
# Journaled Command: nodeset 1 name "MeshFence"
#
# Added Curve 1 to sideset 1
# Journaled Command: sideset 1 add curve 1
#
# Journaled Command: sideset 1 name "MeshFence"
#
# Added Curve 2 to nodeset 100
# Added Curve 5 to nodeset 100
# Journaled Command: nodeset 100 add curve 2 5
#
# Journaled Command: nodeset 100 name "Substrate"
#
# Added Curve 2 to sideset 100
# Added Curve 5 to sideset 100
# Journaled Command: sideset 100 add curve 2 5
#
# Journaled Command: sideset 100 name "Substrate"
#
# Added Curve 2 to sideset 101
# Journaled Command: sideset 101 add curve 2
#
# Journaled Command: sideset 101 name "Substrate-Right"
#
# Added Curve 5 to sideset 102
# Journaled Command: sideset 102 add curve 5
#
# Journaled Command: sideset 102 name "Substrate-Left"
#
# Added Curve 3 to nodeset 200
# Added Curve 4 to nodeset 200
# Journaled Command: nodeset 200 add curve 3 4
#
# Journaled Command: nodeset 200 name "FreeSurface"
#
# Added Curve 3 to sideset 200
# Added Curve 4 to sideset 200
# Journaled Command: sideset 200 add curve 3 4
#
# Journaled Command: sideset 200 name "FreeSurface"
#
# Added Vertex 1 to nodeset 1000
# Journaled Command: nodeset 1000 add vertex 1
#
# Journaled Command: nodeset 1000 name "CA-Right"
#
# Added Vertex 2 to nodeset 2000
# Journaled Command: nodeset 2000 add vertex 2
#
# Journaled Command: nodeset 2000 name "CA-Left"
#
# Added Surface 1 to block 1
# Added Surface 2 to block 1
# Journaled Command: block 1 add surface all
#
# Journaled Command: block 1 name "Liquid"
#
# Journaled Command: block 1 element type QUAD9
#
# Progress
# Saving CUBIT file '/home/greg/projects/cubit_goma_remeshing_tutorial/drop_init_mesh.cub5'
# 0   |    |    |    |    50   |    |    |    |  100
# **********************************************
# Exported:   2 Volumes
#
# ****
# Successfully saved Cubit HDF5 file '/home/greg/projects/cubit_goma_remeshing_tutorial/drop_init_mesh.cub5'
# Journaled Command: save cub5 "drop_init_mesh.cub5" overwrite
#
#
# Using ExodusII API version 8.03 and DB version 8.03 to export "drop_init_mesh.exoII".
# Writing Exodus file
# 0   |    |    |    |    50   |    |    |    |  100
# **************************************************
#
#
# Executive Exodus summary:
#   Number of dimensions     = 2
#   Number of element blocks = 1
#   Number of sidesets       = 5
#   Number of nodesets       = 16
#   Number of bc sets        = 1
#   Number of elements       = 270
#   Number of nodes          = 1141
#
# Finished writing drop_init_mesh.exoII
# Journaled Command: export mesh "drop_init_mesh.exoII" dimension 2 overwrite
#
# v7.5.0-5-g4feea58b-dirty
# /*************************************************************************
# * Goma - Multiphysics finite element software                            *
# * Sandia National Laboratories                                           *
# *                                                                        *
# * Copyright (c) 2022 Goma Developers, National Technology & Engineering  *
# *               Solutions of Sandia, LLC (NTESS)                         *
# *                                                                        *
# * Under the terms of Contract DE-NA0003525, the U.S. Government retains  *
# * certain rights in this software.                                       *
# *                                                                        *
# * This software is distributed under the GNU General Public License.     *
# * See LICENSE file.                                                      *
# \************************************************************************/
#
# PRS, PAS, RRR, KSC, RAC, TAB, DRN, PLH, DAL, IDG, ACK, ACS, RBS, RRL, MMH, SRS
# HKM, RAR, EDW, PKN, SAR, EMB, KT, DSB, DSH, WWO ...
#
#
#
#
# Number of unknowns            = 5374
#
# Number of matrix nonzeroes    = 391066
#
# => Try for soln at t=1e-08 with dt=1e-08 [0 for 0] (BE)
# WARNING: Defaulting on Time step error norm indicators
#  (/home/greg/apps/goma/src/mm_input.c:1584)
# WARNING: Bad elem post process variable count  (/home/greg/apps/goma/src/mm_post_proc.c:12137)
# WARNING: Wall velocity not found : setting to zero
#  (/home/greg/apps/goma/src/bc_special.c:881)
#     N e w t o n  C o n v e r g e n c e  - I m p l i c i t   T i m e   S t e p
#
#    ToD   itn   L_oo    L_1     L_2     L_oo    L_1     L_2   lis  asm/slv (sec)
# -------- --- ------- ------- ------- ------- ------- ------- --- ---------------
# 22:29:58 [0] 1.0e-03 5.1e-01 1.7e-02 1.4e+03 4.1e+05 2.3e+04  1  1.7e-01/7.0e-02
# 22:29:58 [1] 2.7e-04 1.6e-01 4.1e-03 3.3e+02 4.0e+04 1.9e+03  1  1.7e-01/4.0e-02
# 22:29:58 [2] 1.1e-03 3.7e-01 1.1e-02 3.9e+02 5.0e+04 2.9e+03  1  1.8e-01/4.0e-02
# 22:29:59 [3] 6.1e-04 1.7e-01 5.0e-03 1.8e+02 4.0e+04 1.9e+03  1  1.7e-01/5.0e-02
# 22:29:59 [4] 7.7e-04 2.3e-01 6.7e-03 7.5e+01 1.4e+04 6.9e+02  1  1.7e-01/4.0e-02
# 22:29:59 [5] 4.5e-04 9.7e-02 3.2e-03 3.2e+01 5.3e+03 2.1e+02  1  1.8e-01/4.0e-02
# 22:29:59 [6] 2.1e-04 3.4e-02 1.1e-03 7.8e+00 1.2e+03 3.9e+01  1  1.8e-01/5.0e-02
# 22:29:59 [7] 2.5e-05 5.3e-03 1.7e-04                         skp 1.9e-01/0.0e+00
# -------- --- ------- ------- ------- ------- ------- ------- --- ---------------
# scaled solution norms   1.446e+03  7.363e+01  3.186e+02
#
# CONSTANT DELTA_T          [1.4e-01, 1.8e-01, 1.3e-01]
# Predictor-corrector norm: [  1 d  ,   1 v  ,   1 P  ]
#
# => Try for soln at t=2e-08 with dt=1e-08 [1 for 1] (BE)
#
#     N e w t o n  C o n v e r g e n c e  - I m p l i c i t   T i m e   S t e p
#
#    ToD   itn   L_oo    L_1     L_2     L_oo    L_1     L_2   lis  asm/slv (sec)
# -------- --- ------- ------- ------- ------- ------- ------- --- ---------------
# 22:30:00 [0] 4.6e-04 1.4e-01 4.3e-03 1.5e+03 3.9e+05 2.3e+04  1  2.0e-01/5.0e-02
# 22:30:00 [1] 3.7e-04 3.8e-02 1.2e-03 1.9e+01 2.8e+03 7.7e+01  1  1.8e-01/5.0e-02
# 22:30:00 [2] 1.2e-04 3.6e-02 1.0e-03 9.8e+00 1.7e+03 7.3e+01  1  1.7e-01/5.0e-02
# 22:30:00 [3] 5.3e-05 8.9e-03 2.9e-04                         skp 1.8e-01/0.0e+00
# -------- --- ------- ------- ------- ------- ------- ------- --- ---------------
# scaled solution norms   1.443e+03  7.366e+01  3.184e+02
#
# CONSTANT DELTA_T          [3.2e-03, 1.6e-01, 1.3e-01]
# Predictor-corrector norm: [  1 d  ,   1 v  ,   1 P  ]
#
# => Try for soln at t=3e-08 with dt=1e-08 [2 for 2] (BE)
#
#     N e w t o n  C o n v e r g e n c e  - I m p l i c i t   T i m e   S t e p
#
#    ToD   itn   L_oo    L_1     L_2     L_oo    L_1     L_2   lis  asm/slv (sec)
# -------- --- ------- ------- ------- ------- ------- ------- --- ---------------
# 22:30:01 [0] 1.4e-04 2.8e-02 8.6e-04 4.5e+00 1.3e+03 4.2e+01  1  1.7e-01/5.0e-02
# -------- --- ------- ------- ------- ------- ------- ------- --- ---------------
# scaled solution norms   1.444e+03  7.365e+01  3.185e+02
#
# CONSTANT DELTA_T          [8.7e-04, 1.4e-02, 1.9e-04]
# Predictor-corrector norm: [  1 d  ,   1 v  ,   1 P  ]
#
# => Try for soln at t=4e-08 with dt=1e-08 [3 for 3] (BE)
#
#     N e w t o n  C o n v e r g e n c e  - I m p l i c i t   T i m e   S t e p
#
#    ToD   itn   L_oo    L_1     L_2     L_oo    L_1     L_2   lis  asm/slv (sec)
# -------- --- ------- ------- ------- ------- ------- ------- --- ---------------
# 22:30
(BE)
#
#     N e w t o n  C o n v e r g e n c e  - I m p l i c i t   T i m e   S t e p
#
#    ToD   itn   L_oo    L_1     L_2     L_oo    L_1     L_2   lis  asm/slv (sec)
# -------- --- ------- ------- ------- ------- ------- ------- --- ---------------
# 22:30:22 [0] 2.4e-05 1.5e-03 1.3e-04 8.3e-01 2.3e+02 1.3e+01  1  1.7e-01/5.0e-02
# -------- --- ------- ------- ------- ------- ------- ------- --- ---------------
# scaled solution norms   2.684e+02  1.321e+01  5.771e+01
#
# OK  1.7e-03 < 1.5 1.0e-02 [1.3e-04, 1.6e-03, 4.0e-04]
# Predictor-corrector norm: [  1 d  ,   1 v  ,   1 P  ]
#
# => Try for soln at t=0.00984979 with dt=0.000551471 [100 for 100] (BE)
#
#     N e w t o n  C o n v e r g e n c e  - I m p l i c i t   T i m e   S t e p
#
#    ToD   itn   L_oo    L_1     L_2     L_oo    L_1     L_2   lis  asm/slv (sec)
# -------- --- ------- ------- ------- ------- ------- ------- --- ---------------
# 22:30:22 [0] 2.4e-05 1.4e-03 1.3e-04 8.0e-01 2.2e+02 1.3e+01  1  1.8e-01/4.0e-02
# -------- --- ------- ------- ------- ------- ------- ------- --- ---------------
# scaled solution norms   2.602e+02  1.280e+01  5.591e+01
#
# OK  1.7e-03 < 1.5 1.0e-02 [1.3e-04, 1.6e-03, 3.9e-04]
# Predictor-corrector norm: [  1 d  ,   1 v  ,   1 P  ]
# reset delta_t = 0.000150209 to maintain printing frequency
#
# => Try for soln at t=0.01 with dt=0.000150209 [101 for 101] (BE)
#
#     N e w t o n  C o n v e r g e n c e  - I m p l i c i t   T i m e   S t e p
#
#    ToD   itn   L_oo    L_1     L_2     L_oo    L_1     L_2   lis  asm/slv (sec)
# -------- --- ------- ------- ------- ------- ------- ------- --- ---------------
# 22:30:22 [0] 4.0e-06 4.5e-04 1.7e-05 1.0e-01 3.0e+01 1.5e+00  1  1.7e-01/4.0e-02
# -------- --- ------- ------- ------- ------- ------- ------- --- ---------------
# scaled solution norms   2.581e+02  1.269e+01  5.544e+01
#
# OK  5.2e-04 < 1.5 1.0e-02 [8.7e-06, 5.2e-04, 3.4e-05]
# Predictor-corrector norm: [  1 d  ,   1 v  ,   1 P  ]
# 		out of time!
#
# -done
#
#
# Proc 0 runtime:       0.41 Minutes.
# /bin/sh: 1: cannot open algebra.in: No such file
# Traceback (most recent call last):
#   File "/home/greg/.local/bin/meshio", line 8, in <module>
#     sys.exit(main())
#   File "/home/greg/.local/lib/python3.10/site-packages/meshio/_cli/_main.py", line 52, in main
#     return args.func(args)
#   File "/home/greg/.local/lib/python3.10/site-packages/meshio/_cli/_convert.py", line 53, in convert
#     mesh = read(args.infile, file_format=args.input_format)
#   File "/home/greg/.local/lib/python3.10/site-packages/meshio/_helpers.py", line 71, in read
#     return _read_file(Path(filename), file_format)
#   File "/home/greg/.local/lib/python3.10/site-packages/meshio/_helpers.py", line 90, in _read_file
#     raise ReadError(f"File {path} not found.")
# meshio._exceptions.ReadError: File out_spreading_drop_last.e not found.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 main()
#
# Cell In [5], line 23, in main()
#      21 generate_initial_mesh()
#      22 run_goma()
# ---> 23 convert_results()
#
# Cell In [6], line 9, in convert_results()
#       7 subprocess.run( algebra_command, shell=True )
#       8 meshio_command = "meshio convert out_spreading_drop_last.e out_spreading_drop.xdmf"
# ----> 9 subprocess.check_call( meshio_command, shell=True )
#
# File ~/mambaforge3/lib/python3.10/subprocess.py:369, in check_call(*popenargs, **kwargs)
#     367     if cmd is None:
#     368         cmd = popenargs[0]
# --> 369     raise CalledProcessError(retcode, cmd)
#     370 return 0
#
# CalledProcessError: Command 'meshio convert out_spreading_drop_last.e out_spreading_drop.xdmf' returned non-zero exit status 1.

# %%
results = pyvista.read( "./out_spreading_drop.xdmf" )
displacement = numpy.transpose( numpy.array( [ results["DMX"], results["DMY"], numpy.zeros( len(results["DMX"]) ) ] ) )
results.add_field_data( displacement, "disp" )
warped = results.warp_by_vector( vectors="disp", factor=1.0 )
warped.plot( scalars=results['disp'], cpos='xy' )
